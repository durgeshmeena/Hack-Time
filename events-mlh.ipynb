# %%
import requests as r 
from bs4 import BeautifulSoup
import regex as re 
import numpy as np
import pandas as pd

# %%
session = r.Session()

# %%
s = session.get('https://mlh.io/seasons/2022/events')

# %%
soup = BeautifulSoup(s.content, 'html.parser')

# %%
event = soup.find('div', class_='event')

# %%
event
# Out:
# <div class="event event-209459 col-lg-3 col-md-4 col-sm-6" itemscope="" itemtype="http://schema.org/Event">
# <div class="event-wrapper">
# <a class="event-link" href="https://dh21.dubhacks.co/" itemprop="url" target="_blank" title="DubHacks">
# <div class="inner">
# <div class="image-wrap"><img alt="Dh splash" src="https://s3.amazonaws.com/assets.mlh.io/events/splashes/000/209/459/thumb/DH_Splash.png?1634302894"/></div>
# <div class="event-logo"><img alt="Dh logo" src="https://s3.amazonaws.com/assets.mlh.io/events/logos/000/209/459/thumb/DH_Logo.png?1634302894"/></div>
# <h3 class="event-name" itemprop="name">DubHacks</h3>
# <p class="event-date">Oct 23rd - 24th        </p>
# <meta content="2021-10-23" itemprop="startDate"/>
# <meta content="2021-10-24" itemprop="endDate"/>
# <div class="event-location" itemprop="location" itemscope="" itemtype="http://schema.org/City">
# <span itemprop="city">Everywhere</span>,
#           <span itemprop="state">Worldwide</span>
# </div>
# <div class="event-hybrid-notes">
# <span>Digital Only</span>
# </div>
# </div>
# </a> </div>
# </div>

# %%
# print(event.find('h3', class_="event-name").text)
# print(event.find('p', class_="event-date").text)
# print(event.find('span', itemprop="city").text, event.find('span', itemprop="state").text)
# print(event.find_all('span'))
# print(event.find('img')['src'])
# for d in event.find_all('span'):
#     print(d.text) 

# date = event.find_all('meta')
# s = pd.to_datetime(date[0]['content'], yearfirst=True)
# e = pd.to_datetime(date[1]['content'], yearfirst=True)

# print(s, e)

# print(e-s)

# %%
events = soup.find_all('div', class_='event')
data = {}
category = []
name = []
date_time = []
length = []
link = []
image = []
location = []
type_ = []

# %%
for event in events:
    # print('Name- ', event.find('h3', class_="event-name").text)
    # print('Date- ', event.find('p', class_="event-date").text)
    # print('Link- ',event.find('a')['href'])
    # print('Image- ',event.find('img')['src'])
    # place_type = event.find_all('span')
    # print('Location-', place_type[0].text+', '+place_type[1].text)
    # print('Type- ', place_type[2].text)
    # print('\n','##########################','\n')

    place_type = event.find_all('span')

    category.append('MLH')
    name.append(event.find('h3', class_="event-name").text)
    date_time.append( event.find('p', class_="event-date").text+'( EST )' )

    date = event.find_all('meta')
    s = pd.to_datetime(date[0]['content'], yearfirst=True)
    e = pd.to_datetime(date[1]['content'], yearfirst=True)

    length.append(e-s)
    link.append( event.find('a')['href'] )
    image.append( event.find('img')['src'] )
    location.append( place_type[0].text+', '+place_type[1].text )
    type_.append( place_type[2].text )

# %%
mlh_data = {
    'Category':category, 
    'Name':name,  
    'Date/Time':date_time, 
    'Length':length, 
    'Link':link, 
    'Image':image, 
    'Location':location, 
    'Type':type_
}

# %%
df_mlh = pd.DataFrame(mlh_data)
df_mlh.to_csv('data_mlh.csv', mode='a', index=False)

# %%
df = pd.read_csv('data_mlh.csv')

# %%
df
# Out:
#    Category                   Name                       Date/Time  Length  \
# 0       MLH               DubHacks  Oct 23rd - 24th        ( EST )  1 days
# 1       MLH               HackDuke  Oct 23rd - 24th        ( EST )  1 days
# 2       MLH            hackCBS 4.0  Oct 29th - 31st        ( EST )  2 days
# 3       MLH           HackNITR 3.0  Oct 29th - 31st        ( EST )  2 days
# 4       MLH         Hack-O-Lantern  Oct 29th - 31st        ( EST )  2 days
# ..      ...                    ...                             ...     ...
# 60      MLH             DandyHacks  Oct 22nd - 24th        ( EST )  2 days
# 61      MLH  Hack Around the World  Oct 22nd - 24th        ( EST )  2 days
# 62      MLH     Hack This Fall 2.0  Oct 22nd - 24th        ( EST )  2 days
# 63      MLH        Pitt Challenge   Oct 22nd - 24th        ( EST )  2 days
# 64      MLH             PlutoHacks  Oct 22nd - 24th        ( EST )  2 days
#
#                                                  Link  \
# 0                           https://dh21.dubhacks.co/
# 1                          https://2021.hackduke.org/
# 2                               https://hackcbs.tech/
# 3                         https://hacknitr.tech/#home
# 4   https://organize.mlh.io/participants/events/74...
# ..                                                ...
# 60                            https://dandyhacks.net/
# 61  https://organize.mlh.io/participants/events/74...
# 62                         https://hackthisfall.tech/
# 63                         https://pittchallenge.com/
# 64                            https://plutohacks.com/
#
#                                                 Image                Location  \
# 0   https://s3.amazonaws.com/assets.mlh.io/events/...   Everywhere, Worldwide
# 1   https://s3.amazonaws.com/assets.mlh.io/events/...  Durham, North Carolina
# 2   https://s3.amazonaws.com/assets.mlh.io/events/...   Everywhere, Worldwide
# 3   https://s3.amazonaws.com/assets.mlh.io/events/...   Everywhere, Worldwide
# 4   https://s3.amazonaws.com/assets.mlh.io/events/...   Everywhere, Worldwide
# ..                                                ...                     ...
# 60  https://s3.amazonaws.com/assets.mlh.io/events/...   Everywhere, Worldwide
# 61  https://s3.amazonaws.com/assets.mlh.io/events/...   Everywhere, Worldwide
# 62  https://s3.amazonaws.com/assets.mlh.io/events/...   Everywhere, Worldwide
# 63  https://s3.amazonaws.com/assets.mlh.io/events/...   Everywhere, Worldwide
# 64  https://s3.amazonaws.com/assets.mlh.io/events/...   Everywhere, Worldwide
#
#                        Type
# 0              Digital Only
# 1   Hybrid, In-Person Focus
# 2              Digital Only
# 3              Digital Only
# 4              Digital Only
# ..                      ...
# 60  Hybrid, In-Person Focus
# 61             Digital Only
# 62             Digital Only
# 63             Digital Only
# 64             Digital Only
#
# [65 rows x 8 columns]
