# %%
import requests as r 
from bs4 import BeautifulSoup
import pandas as pd

# %%
session = r.Session()

# %%
s = session.get('https://www.hackerearth.com/challenges/')

# %%
soup = BeautifulSoup(s.content, 'html.parser')

# %%
event = soup.find('div', class_='challenge-card-modern')

# %%
# event

# %%
# print(event.find('span', class_="challenge-list-title").text)
# print(event.find('a', class_="challenge-card-link")['href']) 
# c_t = event.find('div', class_="challenge-type").text
# c_t = c_t.split('\n')[2].split(' ')[-1]
# print(c_t)
# comp = event.find('div' , class_='company-details').text.split('\n')[1]
# print(comp)

# print(event.find('div', class_="registrations").text.split('\n')[1])

# print(event.find_all('div', class_="caps")[1].text) 

# print(event.find('div', class_="event-image")['style'].split("'")[1])

# %%
events = soup.find_all('div', class_='challenge-card-modern')
category = []
name = []
challenge = []
status = []
link = []
image = []
company = []
registration = []

# %%
# category.append('Hackathons')
# name.append(event.find('span', class_="challenge-list-title").text)
# challenge.append(event.find('div', class_="challenge-type").text.split('\n')[2].split(' ')[-1])
# if event.find_all('div', class_="caps")[1].text =="ENDS IN":
#     status.append('Live')
# else:
#     status.append(event.find('div', class_='date').text)    

# company.append(event.find('div' , class_='company-details').text.split('\n')[1])
# registration.append(event.find('div', class_="registrations").text.split('\n')[1])
# link.append( event.find('a', class_="challenge-card-link")['href'] )
# image.append( event.find('div', class_="event-image")['style'].split("'")[1] )

# %%
# print(category, name, challenge, status, company, registration,link, image)

# %%
for event in events:
    if event.find('div' , class_='company-details') and event.find('div', class_="event-image"):
        category.append('Hackathons')
        name.append(event.find('span', class_="challenge-list-title").text)
        challenge.append(event.find('div', class_="challenge-type").text.split('\n')[2].split(' ')[-1])
        if event.find_all('div', class_="caps")[1].text =="ENDS IN":
            status.append('Live')
        else:
            status.append(event.find('div', class_='date').text)    

        company.append(event.find('div' , class_='company-details').text.split('\n')[1])
        registration.append(event.find('div', class_="registrations").text.split('\n')[1])
        link.append( event.find('a', class_="challenge-card-link")['href'] )
        image.append( event.find('div', class_="event-image")['style'].split("'")[1] )

# %%
hackerearth_data = {
    'Category':category, 
    'Name':name,  
    'Type':challenge, 
    'Status':status, 
    'Company':company, 
    'Registration':registration, 
    'Link':link, 
    'image':image
}

# %%
df_hackerearth = pd.DataFrame(hackerearth_data)
df_hackerearth.to_csv('data_hackerearth.csv', mode='a', index=False)

# %%
df = pd.read_csv('data_hackerearth.csv')

# %%
df
# Out:
#       Category                                               Name       Type  \
# 0   Hackathons                           The World After Covid-19  HACKATHON
# 1   Hackathons                              IBM Z Student Contest  HACKATHON
# 2   Hackathons                                 Shell.ai Hackathon   LEARNING
# 3   Hackathons                 Integrated Digital Label Hackathon  HACKATHON
# 4   Hackathons  LocoNav Senior Software Engineer Hiring Challenge     HIRING
# 5   Hackathons  Dravya Python and ML/Deep Learning Developer H...     HIRING
# 6   Hackathons          Dravya AWS Administrator Hiring Challenge     HIRING
# 7   Hackathons  Navi Software Development Engineer Hiring Chal...     HIRING
# 8   Hackathons           SRIB Software Developer Hiring Challenge     HIRING
# 9   Hackathons  Tech Mahindra Java Full Stack Software Enginee...     HIRING
# 10  Hackathons       Angel One Software Engineer Hiring Challenge     HIRING
# 11  Hackathons  Angel One Mobile Application Developer Hiring ...     HIRING
# 12  Hackathons          TCS Full Stack Developer Hiring Challenge     HIRING
# 13  Hackathons        MishiPay Software Engineer Hiring Challenge     HIRING
# 14  Hackathons                                   Juspay Hackathon  HACKATHON
# 15  Hackathons                                          FLIP Fest  HACKATHON
# 16  Hackathons        ZS Ace-a-Thon (Women only Hiring Challenge)     HIRING
# 17  Hackathons          FloBiz Android Developer Hiring Challenge     HIRING
# 18  Hackathons       Dravya Full Stack Developer Hiring Challenge     HIRING
# 19  Hackathons  Dravya Mobile Application Developer Hiring Cha...     HIRING
# 20  Hackathons        Omnicell Tech Challenge for Java Developers     HIRING
# 21  Hackathons                          Prasaga Use Case Ideathon  HACKATHON
# 22  Hackathons                                            Ecothon  HACKATHON
# 23  Hackathons                 I3 – Innovate – Ideate – Implement  HACKATHON
# 24  Hackathons       Clevertap Frontend Engineer Hiring Challenge     HIRING
# 25  Hackathons           INNOVATE - Algorand Blockchain Hackathon  HACKATHON
# 26  Hackathons  HealthifyMe Senior Backend Developer Hiring Ch...     HIRING
# 27  Hackathons                 Amazon SDE I & II Hiring Challenge     HIRING
# 28  Hackathons      Tara Capital Quant Developer Hiring Challenge     HIRING
# 29  Hackathons             Juspay Developer Hiring challenge 2021     HIRING
# 30  Hackathons        Clevertap Backend Engineer Hiring Challenge     HIRING
# 31  Hackathons      Tecnotree Java/C++ Developer Hiring Challenge     HIRING
# 32  Hackathons             Saviynt Java Engineer Hiring Challenge     HIRING
# 33  Hackathons  Impact Analytics Front-End Developer Hiring Ch...     HIRING
# 34  Hackathons      Infinx Java Product Engineer Hiring Challenge     HIRING
# 35  Hackathons          JustAnswer Sr.Software Engineer Challenge     HIRING
# 36  Hackathons             Infinx Data Structure Hiring Challenge     HIRING
# 37  Hackathons                 Kongsberg Digital Hiring Challenge     HIRING
#
#                   Status                               Company  \
# 0                   Live                            KPMG MALTA
# 1                   Live                                 IBM Z
# 2                   Live                              Shell.ai
# 3                   Live                                 Bayer
# 4                   Live                               LocoNav
# 5                   Live                                Dravya
# 6                   Live                                Dravya
# 7                   Live                                  Navi
# 8                   Live                               Samsung
# 9                   Live                         Tech Mahindra
# 10                  Live                             Angel One
# 11                  Live                             Angel One
# 12                  Live                             TCS India
# 13                  Live                          MishiPay Ltd
# 14                  Live                                Juspay
# 15                  Live                           Dapper Labs
# 16                  Live                         ZS Associates
# 17                  Live                                FloBiz
# 18                  Live                                Dravya
# 19                  Live                                Dravya
# 20                  Live                              Omnicell
# 21                  Live                               Prasaga
# 22                  Live                           HackerEarth
# 23                  Live                       Bharat Bill Pay
# 24                  Live                             CleverTap
# 25                  Live                              Algorand
# 26  Oct 29, 06:00 PM IST                           HealthifyMe
# 27  Oct 29, 06:00 PM IST   Amazon Development Centre Pvt. Ltd.
# 28  Oct 29, 06:00 PM IST                 Tara Capital Partners
# 29  Oct 29, 06:00 PM IST                                Juspay
# 30  Oct 29, 06:00 PM IST                             CleverTap
# 31  Oct 29, 06:00 PM IST                             Tecnotree
# 32  Nov  5, 06:00 PM IST                               Saviynt
# 33  Nov  5, 06:00 PM IST                      Impact Analytics
# 34  Nov  5, 06:00 PM IST                                Infinx
# 35  Nov 19, 06:00 PM IST                           Just Answer
# 36  Nov 19, 06:00 PM IST                                Infinx
# 37  Nov 26, 06:00 PM IST                     Kongsberg Digital
#
#                                          Registration  \
# 0                                                2052
# 1                                               16770
# 2                                                 715
# 3                                                2371
# 4                             CTC INR  15.0L -  30.0L
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                    Best in industry
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13   12 - 24 LPA (additionally 20% bonus, stock op...
# 14                                               2483
# 15                                               2183
# 16                                                NaN
# 17                            CTC INR  12.0L -  35.0L
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                               2706
# 22                                                691
# 23                                                491
# 24                                                NaN
# 25                                                162
# 26                               Best in the industry
# 27                                   Best in industry
# 28                            As per market standards
# 29                                         8 - 30 LPA
# 30                                                NaN
# 31                                   Best in industry
# 32                                   Best in industry
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                          As per industry standards
#
#                                                  Link  \
# 0   https://www.hackerearth.com/challenges/hackath...
# 1   https://www.hackerearth.com/challenges/hackath...
# 2    /challenges/competitive/shell-ai-hackathon-2021/
# 3   https://www.hackerearth.com/challenges/hackath...
# 4   /challenges/hiring/loconav-senior-software-eng...
# 5   /challenges/hiring/dravya-python-and-ml-deep-l...
# 6   /challenges/hiring/dravya-aws-administrator-hi...
# 7   /challenges/hiring/navi-software-development-e...
# 8   /challenges/hiring/srib-software-developer-hir...
# 9   /challenges/hiring/tech-mahindra-java-full-sta...
# 10  /challenges/hiring/angel-one-software-engineer...
# 11  /challenges/hiring/angel-one-mobile-applicatio...
# 12  /challenges/hiring/tcs-full-stack-developer-oc...
# 13  /challenges/hiring/mishipay-software-engineer-...
# 14  https://www.hackerearth.com/challenges/hackath...
# 15  https://www.hackerearth.com/challenges/hackath...
# 16    /challenges/hiring/zs-ace-a-thon-women-only-hc/
# 17  /challenges/hiring/flobiz-android-developer-hi...
# 18  /challenges/hiring/dravya-full-stack-developer...
# 19  /challenges/hiring/dravya-mobile-application-d...
# 20  /challenges/hiring/omnicell-tech-challenge-for...
# 21  https://www.hackerearth.com/challenges/hackath...
# 22  https://www.hackerearth.com/challenges/hackath...
